# %% [markdown]
# <a href="https://colab.research.google.com/github/ayuksekdag/winacademy_python_dna/blob/main/countries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_by_birth_rate")
countries = tables[0]
countries
# Out:
#                  Country/territory  PRB 2022[1]  CIA WF 2023[2]
# 0                      Afghanistan         36.0           34.79
# 1                          Albania         10.0           12.48
# 2                          Algeria         22.0           17.84
# 3                          Andorra          6.0            6.87
# 4                           Angola         39.0           41.42
# ..                             ...          ...             ...
# 229  Turks and Caicos Islands (UK)          NaN           13.24
# 230   United States Virgin Islands          NaN           11.35
# 231     Wallis and Futuna (France)          NaN           12.05
# 232           Palestine/Gaza Strip          NaN           27.20
# 233                   World (2020)          NaN           18.10
#
# [234 rows x 3 columns]

# %%
countries.columns
# Out:
# Index(['Country/territory', 'PRB 2022[1]', 'CIA WF 2023[2]'], dtype='object')

# %%
countries.columns = ['country','prb2022','ciawf2023']

# %%
display(countries.head(5))
# Out:
#        country  prb2022  ciawf2023
# 0  Afghanistan     36.0      34.79
# 1      Albania     10.0      12.48
# 2      Algeria     22.0      17.84
# 3      Andorra      6.0       6.87
# 4       Angola     39.0      41.42

# %% [markdown]
# All countries
#
# Select all countries, but not the dependendent territories. Include all columns.

# %%
countries[countries['country'].str.contains('\(')].sort_values(by='country')
# Out:
#                                                country  prb2022  ciawf2023
# 196                                      Anguilla (UK)      NaN      11.90
# 197                                Aruba (Netherlands)      NaN      11.69
# 198                                       Bermuda (UK)      NaN      10.97
# 200                                Cayman Islands (UK)      NaN      11.62
# 203                         Cook Islands (New Zealand)      NaN      12.34
# 204                              Curacao (Netherlands)      NaN      13.07
# 56                                Eswatini (Swaziland)     24.0      22.83
# 205                            Faroe Islands (Denmark)      NaN      14.94
# 206                                     Gibraltar (UK)      NaN      13.84
# 207                                Greenland (Denmark)      NaN      13.66
# 208                                Guadeloupe (France)     11.0        NaN
# ...
